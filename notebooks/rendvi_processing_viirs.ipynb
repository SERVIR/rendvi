# %%
import datetime
import pandas as pd
from pprint import pprint
from sidecar import Sidecar
from ipyleaflet import Map, basemaps, DrawControl, TileLayer, LayersControl

# %%
# Define a method for displaying Earth Engine image tiles to folium map.
def add_ee_layer(self,eeImageObject, visParams, name):
    mapID = ee.Image(eeImageObject).getMapId(visParams)
    tiles = TileLayer(
        url = mapID['tile_fetcher'].url_format,
        attribution="Map Data © <a href=’https://earthengine.google.com’>Google Earth Engine</a>",
        name = name,
    )
    self.add_layer(tiles)
    
Map.add_ee_layer = add_ee_layer

# %%
m = Map(center=(0,35),zoom=8,basemap=basemaps.CartoDB.Positron)
m.scroll_wheel_zoom = True

draw_control = DrawControl()
draw_control.polygon = {
    "shapeOptions": {
        "fillColor": "#6be5c3",
        "color": "#6be5c3",
        "fillOpacity": 1.0
    },
    "drawError": {
        "color": "#dd253b",
        "message": "I'm sorry Dave, I'm afraid I can't do that"
    },
    "allowIntersection": False
}
draw_control.circle = {
    "shapeOptions": {
        "fillColor": "#efed69",
        "color": "#efed69",
        "fillOpacity": 1.0
    }
}
draw_control.rectangle = {
    "shapeOptions": {
        "fillColor": "#fca45d",
        "color": "#fca45d",
        "fillOpacity": 1.0
    }
}

m.add_control(draw_control)

m.add_control(LayersControl(position='topright'))

# %%
sc = Sidecar(title='EE Map')

with sc:
    display(m)
# Out:
# Map(center=[0, 35], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
import ee
ee.Initialize()
import rendvi
from rendvi import eeCollections

# %%
viirs = eeCollections.VNP09GA['imageCollection']

# %%
masked = rendvi.Masking.applyViirs(viirs)
withNdvi = rendvi.Utils.addNDBand(masked,
                                  b1=eeCollections.VNP09GA['nir'],
                                  b2=eeCollections.VNP09GA['red'],
                                  outName='ndvi')

# %%
comp = ee.Image(viirs.sort('system:time_start',False).first())

m.add_ee_layer(comp,{'bands':"M11,M7,M4",'min':50,'max':5500,'gamma':1.5},'VIIRS')

# %%
comp = ee.Image(withNdvi.sort('system:time_start',False).first())

m.add_ee_layer(comp,{'bands':"ndvi",'min':-0.2,'max':1,'palette':'gray,beige,green,darkgreen'},'NDVI')
m.add_ee_layer(comp.select('qa').selfMask(),{"bands":'qa','min':0,'max':8,'palette':'black,pink,red,orange,white,gray,cyan,yellow,blue'},'QA')

# %%
# time information to handle image collection
iniYear = 2018
endYear = 2020

today = ee.Date(datetime.datetime.now().strftime('%Y-%m-%d')).advance(-7,'day')

# convert start and end dates to EE date objects
eeIni = ee.Date.fromYMD(iniYear,1,1,)
eeEnd = ee.Date.fromYMD(endYear,12,31)

# make list of years for loop processing
years = ee.List.sequence(iniYear,endYear)

# %%
full = rendvi.Rendvi(withNdvi,'ndvi')

# %%
dekads = full.getDekadImages(years,includeQa=True)

# %%
climo = ee.ImageCollection("projects/servir-e-sa/reNDVI_climatology")

# climo = climo.map(lambda x: x.divide(10000).set('system:time_start',x.get('system:time_start')))

# %%
iniDekad = ee.Image(dekads.imageCollection.sort("system:time_start").toList(7).get(-1))

# m.add_ee_layer(iniDekad,{'bands':"ndvi",'min':-0.2,'max':1,'palette':'gray,beige,green,darkgreen'},'Dekad Composite')
# m.add_ee_layer(iniDekad,{'bands':"pctClouds",'min':0,'max':1,'palette':'white,lightblue,blue,darkblue,black'},'Clouds')

# %%
despiked = dekads.applyDespike(window=30,step=10)

# x = ee.Image(despiked.imageCollection.sort("system:time_start").first())
# m.add_ee_layer(x,{'bands':"ndvi",'min':-0.2,'max':1,'palette':'gray,beige,green,darkgreen'},'Despiked')
# m.add_ee_layer(x,{'bands':"despiked",'min':0,'max':1,'palette':'black,red'},'Despike Mask')

# %%
backFilled = despiked.climatologyBackFill(climo,keepBandPattern="^(de|pct|nClear).*")

# x = ee.Image(backFilled.imageCollection.sort("system:time_start").first())
# m.add_ee_layer(x,{'bands':"ndvi",'min':-0.2,'max':1,'palette':'gray,beige,green,darkgreen'},'Back filled')
# m.add_ee_layer(x,{'bands':"climatologyFilled",'min':0,'max':1,'palette':'black,red'},'Back filled Mask')

# %%
kernel = ee.Kernel.square(7.5,"pixels")
spatialSmoothed = backFilled.spatialSmoothing(kernel,zThreshold=1,keepBandPattern="^(clima|de|pct|nClear|t).*")

# %%
# x = ee.Image(spatialSmoothed.imageCollection.sort("system:time_start").first())
# m.add_ee_layer(x,{'bands':"ndvi",'min':-0.2,'max':1,'palette':'gray,beige,green,darkgreen'},'Spatial smoothed')
# m.add_ee_layer(x,{'bands':"spatialSmoothed",'min':0,'max':1,'palette':'black,red'},'Spatial Smoothed Mask')

# %%
smoothed = spatialSmoothed.applySmoothing(window=50,keepBandPattern="^(clima|de|pct|nClear|sp).*")

# %%
final = ee.Image(smoothed.imageCollection.sort("system:time_start").first())

# m.add_ee_layer(final,{'bands':"ndvi",'min':-0.2,'max':1,'palette':'Gray,beige,green,darkgreen'},'Smoothed')
# m.add_ee_layer(final,{'bands':"temporalFilled",'min':0,'max':1,'palette':'black,red'},'Smoothed Mask')

# %%
# geo = ee.Geometry.Point([36.8412,-1.3584]) # Nairobi

# x = backFilled.imageCollection.getRegion(geo,250).getInfo()
# y = spatialSmoothed.imageCollection.getRegion(geo,250).getInfo()
# z = smoothed.imageCollection.getRegion(geo,250).getInfo()

# %%
# def eeRegion_to_dataFrame(result):
#     df = pd.DataFrame(result[1:])
#     df.columns = result[0]
#     df["date"]= pd.to_datetime([t['value']*1e6 if type(t)==dict else t*1e6 for t in df["time"]] )
#     df.index = df.date
#     return df

# dfx = eeRegion_to_dataFrame(x)
# dfy = eeRegion_to_dataFrame(y)
# dfz = eeRegion_to_dataFrame(z)

# %%
# fig = plt.figure(figsize=(10,8))
# ax = dfx.ndvi.plot(marker='o')

# dfy.ndvi.plot(marker='x',ax=ax)
# dfz.ndvi.plot(marker='*',ax=ax)

# ax.set_ylim(0.2,0.95)
# plt.show()

# %%
# !earthengine --no-use_cloud_api task list

# %%
def formatOutput(img):
    ndvi = img.select('ndvi').multiply(10000).int16()
    others = img.select('^(clima|de|pct|sp|tem).*').multiply(100).uint8()
    
    return ee.Image.cat([ndvi,others]).updateMask(landMask)\
        .set('system:time_start',img.date().millis())

landMask = ee.Image("users/kelmarkert/public/landMask").select("land")
outputs = smoothed.imageCollection.filterDate(eeIni.advance(9,'month'),eeEnd).map(formatOutput).sort('system:time_start') # eeIni.advance(9,'month'),eeEnd

# %%
exportAsset = "projects/servir-e-sa/rangelands/reNDVI_viirs"
exportRegion = ee.Geometry.Rectangle([33,-5,42,6],'epsg:4326',False)
metadataDict = dict(contact="kel.markert@nasa.gov",ndviScale=0.0001,otherScale=0.01,offset=0,version=0,creationDate=datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%s"))
pyramidingDict = {'.default':"mean",'despiked':'mode','climatologyFilled':'mode','temporalFilled':'mode','spatialSmoothed':'mode'}

# %%
rendvi.batchExport(outputs, 
                   exportRegion, 
                   exportAsset, 
                   prefix="VIIRS_reNDVI", 
                   suffix="v0", 
                   scale=500, 
                   crs='EPSG:4326',
                   metadata=metadataDict, 
                   pyramiding=pyramidingDict
                  )
# Out:
# running export for VIIRS_reNDVI_20200101_v0
# running export for VIIRS_reNDVI_20191221_v0
# running export for VIIRS_reNDVI_20191211_v0
# running export for VIIRS_reNDVI_20191201_v0
# running export for VIIRS_reNDVI_20191121_v0
# running export for VIIRS_reNDVI_20191111_v0
# running export for VIIRS_reNDVI_20191101_v0
# running export for VIIRS_reNDVI_20191021_v0
# running export for VIIRS_reNDVI_20191011_v0
# running export for VIIRS_reNDVI_20191001_v0
# running export for VIIRS_reNDVI_20190921_v0
# running export for VIIRS_reNDVI_20190911_v0
# running export for VIIRS_reNDVI_20190901_v0
# running export for VIIRS_reNDVI_20190821_v0
# running export for VIIRS_reNDVI_20190811_v0
# running export for VIIRS_reNDVI_20190801_v0
# running export for VIIRS_reNDVI_20190721_v0
# running export for VIIRS_reNDVI_20190711_v0
# running export for VIIRS_reNDVI_20190701_v0
# running export for VIIRS_reNDVI_20190621_v0
# running export for VIIRS_reNDVI_20190611_v0
# running export for VIIRS_reNDVI_20190601_v0
# running export for VIIRS_reNDVI_20190521_v0
# running export for VIIRS_reNDVI_20190511_v0
# running export for VIIRS_reNDVI_20190501_v0
# running export for VIIRS_reNDVI_20190421_v0
# running export for VIIRS_reNDVI_20190411_v0
# running export for VIIRS_reNDVI_20190401_v0
# running export for VIIRS_reNDVI_20190321_v0
# running export for VIIRS_reNDVI_20190311_v0
# running export for VIIRS_reNDVI_20190301_v0
# running export for VIIRS_reNDVI_20190221_v0
# running export for VIIRS_reNDVI_20190211_v0
# running export for VIIRS_reNDVI_20190201_v0
# running export for VIIRS_reNDVI_20190121_v0
# running export for VIIRS_reNDVI_20190111_v0
# running export for VIIRS_reNDVI_20190101_v0
# running export for VIIRS_reNDVI_20181221_v0
# running export for VIIRS_reNDVI_20181211_v0
# running export for VIIRS_reNDVI_20181201_v0
# running export for VIIRS_reNDVI_20181121_v0
# running export for VIIRS_reNDVI_20181111_v0
# running export for VIIRS_reNDVI_20181101_v0
# running export for VIIRS_reNDVI_20181021_v0
# running export for VIIRS_reNDVI_20181011_v0
# running export for VIIRS_reNDVI_20181001_v0

# %%
# !earthengine task list
# Out:
# Running command using Cloud API.  Set --no-use_cloud_api to go back to using the API
#
# COW4NZWQY2KIDMKGWFEP37MU  Export.image  VIIRS_reNDVI_20181001_v0                    READY      ---
# GRNFQN5VH6TK3UJPUC4NCQVU  Export.image  VIIRS_reNDVI_20181011_v0                    READY      ---
# A27R6K6S3MI3CS2X2NY2FXSC  Export.image  VIIRS_reNDVI_20181021_v0                    READY      ---
# GVIZNFHWFEUEQFDYSBYDUHWO  Export.image  VIIRS_reNDVI_20181101_v0                    READY      ---
# Z2LHJ7HTHLYMAFULKLUU3GJ2  Export.image  VIIRS_reNDVI_20181111_v0                    READY      ---
# XVTWOKAVCTVCMZWVWSMFVWP5  Export.image  VIIRS_reNDVI_20181121_v0                    READY      ---
# RPALDWHGRFLH3VTBY3TTOGZ5  Export.image  VIIRS_reNDVI_20181201_v0                    READY      ---
# 7CGXTXYPGFSY6YQGNJWQWB6V  Export.image  VIIRS_reNDVI_20181211_v0                    READY      ---
# 7NOIKRA4GVR3OIVJVVIJ42MI  Export.image  VIIRS_reNDVI_20181221_v0                    READY      ---
# I5HGKQF7ZORN57SNVK5UZ4VG  Export.image  VIIRS_reNDVI_20190101_v0                    READY      ---
# OWYUABV3Q5BQ7AS66YBZWMCE  Export.image  VIIRS_reNDVI_20190111_v0                    READY      ---
# Z3YW34HUIQ6LJAS2LJSDGGYN  Export.image  VIIRS_reNDVI_20190121_v0                    READY      ---
# YXDDIATCJEVX2AZMV72A7L5A  Export.image  VIIRS_reNDVI_20190201_v0                    READY      ---
# 2CHJCZNZHKR6SOCEMF6WUXWV  Export.image  VIIRS_reNDVI_20190211_v0                    READY      ---
# MR5JG5E4LXIJPOPIUVQ2YK26  Export.image  VIIRS_reNDVI_20190221_v0                    READY      ---
# W65MSRLCWRCQIE46WCRLTWZF  Export.image  VIIRS_reNDVI_20190301_v0                    READY      ---
# EIU3TWODGUSZHBF5L4B6M6H2  Export.image  VIIRS_reNDVI_20190311_v0                    READY      ---
# KUMBYV7DQVYDKIKGMNM53EGA  Export.image  VIIRS_reNDVI_20190321_v0                    READY      ---
# CTEFOBLH3YAQQKZLMMEERYAD  Export.image  VIIRS_reNDVI_20190401_v0                    READY      ---
# ARILOXZWXHBUGFC2KPT56HUW  Export.image  VIIRS_reNDVI_20190411_v0                    READY      ---
# EAAHVVVU7CTYXKL7MMH6URI5  Export.image  VIIRS_reNDVI_20190421_v0                    READY      ---
# ANPJHQQTK4ZSWGQI35ALTNY3  Export.image  VIIRS_reNDVI_20190501_v0                    READY      ---
# SVXW7QA6XIXZO6JN42BUZAKU  Export.image  VIIRS_reNDVI_20190511_v0                    READY      ---
# W6PUFB7B3FUW7WRRTZUPTP22  Export.image  VIIRS_reNDVI_20190521_v0                    READY      ---
# 5M7AX2CW5IB6ZOXLCV3SQY2Z  Export.image  VIIRS_reNDVI_20190601_v0                    READY      ---
# UILIAXQ5JG2X2XX2WOGNNQZ3  Export.image  VIIRS_reNDVI_20190611_v0                    READY      ---
# TCSK4QJEMI7NQSFZ7OBMGLP4  Export.image  VIIRS_reNDVI_20190621_v0                    READY      ---
# J5QRNXUD5DN4EP6FEIVDBWVN  Export.image  VIIRS_reNDVI_20190701_v0                    READY      ---
# CLFZUSJDA326P63YJ7ZBSKHU  Export.image  VIIRS_reNDVI_20190711_v0                    READY      ---
# NZLAYLXGY5AGGYNVM2N5S2RG  Export.image  VIIRS_reNDVI_20190721_v0                    READY      ---
# CDUCHA3PL7COWMXBOMQRDZJ3  Export.image  VIIRS_reNDVI_20190801_v0                    READY      ---
# KYHFZKVIW5262RDALTGNVWMV  Export.image  VIIRS_reNDVI_20190811_v0                    READY      ---
# AS6ZZWSOFGFM3KBJFIJZ3MAQ  Export.image  VIIRS_reNDVI_20190821_v0                    READY      ---
# AWSQZ3XVH7RSLAZGEJSWAZQE  Export.image  VIIRS_reNDVI_20190901_v0                    READY      ---
# 24A7J3SGB2G23OAK3WE7JHXZ  Export.image  VIIRS_reNDVI_20190911_v0                    READY      ---
# QGWL6HHDNWORMYF24UBB5TBW  Export.image  VIIRS_reNDVI_20190921_v0                    READY      ---
# IINCHQMVYNCS2I6Z6LPYWDJH  Export.image  VIIRS_reNDVI_20191001_v0                    READY      ---
# FEF65TCWI2RXWNIQGX7XBQCC  Export.image  VIIRS_reNDVI_20191011_v0                    READY      ---
# EBMDZPUYM3SV44CHSOCH3FDC  Export.image  VIIRS_reNDVI_20191021_v0                    READY      ---
# UG6A2SKH3OHQK5J3KBPINPSL  Export.image  VIIRS_reNDVI_20191101_v0                    READY      ---
# TITBZDIJQDF7EGYBVSJT6JPK  Export.image  VIIRS_reNDVI_20191111_v0                    READY      ---
# WLJW6RUGDMRRZHMPYUKIRWDG  Export.image  VIIRS_reNDVI_20191121_v0                    READY      ---
# ACUZK7JVTO6INPWGPRJNXS5Z  Export.image  VIIRS_reNDVI_20191201_v0                    READY      ---
# EIKDXA5Z4OVCNBKVHDHVEQWA  Export.image  VIIRS_reNDVI_20191211_v0                    READY      ---
# 6VTFP5WMNJNUVH7K2SEUOFEA  Export.image  VIIRS_reNDVI_20191221_v0                    READY      ---
# SQ4BDV7AMWQKT3A2LYGA4VAV  Export.image  VIIRS_reNDVI_20200101_v0                    READY      ---
# UPVJEEHJ2C72UMCGUXPFLIZJ  Export.image  VIIRS_reNDVI_20161001_v0                    READY      ---
# 63HH2C76V3H3NDXHGH5LRYUV  Export.image  VIIRS_reNDVI_20161011_v0                    READY      ---
# WOJUCIWVTV73I7EAFL6E6FXM  Export.image  VIIRS_reNDVI_20161021_v0                    READY      ---
# MNYFAT5RLFR54VM5KBYSTEAM  Export.image  VIIRS_reNDVI_20161101_v0                    READY      ---
# QFCIAE63FJBFI77YRZ5IBO5U  Export.image  VIIRS_reNDVI_20161111_v0                    READY      ---
# YHKHLGRCB65B2WQB3MKLGT3G  Export.image  VIIRS_reNDVI_20161121_v0                    READY      ---
# 45AXGAOQWUBML23CS77TKXDL  Export.image  VIIRS_reNDVI_20161201_v0                    READY      ---
# HBAXA6XOELG3XUCP33657IJK  Export.image  VIIRS_reNDVI_20161211_v0                    READY      ---
# 4HLQ27L47G3D7QDIKFAEKSUZ  Export.image  VIIRS_reNDVI_20161221_v0                    READY      ---
# XALNTAFWTXGPMW4JJ56XM6XN  Export.image  VIIRS_reNDVI_20170101_v0                    READY      ---
# WQ77LE22AQ7KKZGSRGP747B5  Export.image  VIIRS_reNDVI_20170111_v0                    READY      ---
# 2SYC7GFKK3D4H4YJPXENOQAA  Export.image  VIIRS_reNDVI_20170121_v0                    READY      ---
# 3DKSR4NBOTGG3VBXUEMKPF7B  Export.image  VIIRS_reNDVI_20170201_v0                    READY      ---
# Z232QH6PAXDYUAPATWYDZW74  Export.image  VIIRS_reNDVI_20170211_v0                    READY      ---
# 5S36NAJHWLD54KBCJSAOFPOT  Export.image  VIIRS_reNDVI_20170221_v0                    READY      ---
# O3SJEE6AORQ6Q2QABXBOJMXP  Export.image  VIIRS_reNDVI_20170301_v0                    READY      ---
# 5AES5SE5UVPPP3PLA3P3UU4F  Export.image  VIIRS_reNDVI_20170311_v0                    READY      ---
# RQDBOECAXDVSXGWBR2QLTW6D  Export.image  VIIRS_reNDVI_20170321_v0                    READY      ---
# G3722V4CKJNB5RIYLFFP6F72  Export.image  VIIRS_reNDVI_20170401_v0                    READY      ---
# HMHKZAFO3IYFEH3HFTFJK7TV  Export.image  VIIRS_reNDVI_20170411_v0                    READY      ---
# YFKGLNAMUGBINW6WYWLPUZVP  Export.image  VIIRS_reNDVI_20170421_v0                    READY      ---
# ZRUUEGYCVFI7HXJH7Y2ATDPG  Export.image  VIIRS_reNDVI_20170501_v0                    READY      ---
# BVCFOJNAMKX5DLOHQRCXS5IW  Export.image  VIIRS_reNDVI_20170511_v0                    READY      ---
# 2YI6O6LOQDJUSXMCLIB7BBCO  Export.image  VIIRS_reNDVI_20170521_v0                    READY      ---
# 2VKKV4Z4TJE72MGP5XQXIQUT  Export.image  VIIRS_reNDVI_20170601_v0                    READY      ---
# 5UW35QNUY54BWFG2MXYKLVZI  Export.image  VIIRS_reNDVI_20170611_v0                    READY      ---
# TOIR2MK3GARUX4C4VOEPNINW  Export.image  VIIRS_reNDVI_20170621_v0                    READY      ---
# FB5ZRMTKXJFDSYH5R5QA4AGT  Export.image  VIIRS_reNDVI_20170701_v0                    READY      ---
# DIHL7VKJJDSZKDJE65WQTPVA  Export.image  VIIRS_reNDVI_20170711_v0                    READY      ---
# D5CJJN5UNPBGSMOZY27F6RS7  Export.image  VIIRS_reNDVI_20170721_v0                    READY      ---
# LXVUKMULRG4CWIXZTHHODJ3I  Export.image  VIIRS_reNDVI_20170801_v0                    READY      ---
# WJ252FVSHKWVFQYN2YSZPDPG  Export.image  VIIRS_reNDVI_20170811_v0                    READY      ---
# MJ2ECO2IZTM7NWJIFQ5SD6BL  Export.image  VIIRS_reNDVI_20170821_v0                    READY      ---
# TKGJKI4M255LPLKO6HEHUVQI  Export.image  VIIRS_reNDVI_20170901_v0                    READY      ---
# K6KZZ7TTXCN6GWOT6BRWSNR7  Export.image  VIIRS_reNDVI_20170911_v0                    READY      ---
# 5GJQEZRNWBDULJ6O3HFNXLND  Export.image  VIIRS_reNDVI_20170921_v0                    READY      ---
# 2YPQT7KLI6DBJKGJ4QY6OW3E  Export.image  VIIRS_reNDVI_20171001_v0                    READY      ---
# BHJCDWNCDGLW6R7DCB4PZZAI  Export.image  VIIRS_reNDVI_20171011_v0                    READY      ---
# LNWTC6KON4IHD336LNDFADKL  Export.image  VIIRS_reNDVI_20171021_v0                    READY      ---
# YZPPVEEXFDT46O55QUUIN6MY  Export.image  VIIRS_reNDVI_20171101_v0                    READY      ---
# ZBBSQ7OWDENOZP6UQVPDPKRH  Export.image  VIIRS_reNDVI_20171111_v0                    READY      ---
# FGB5AT7KXD3VAXFQ76THYVUH  Export.image  VIIRS_reNDVI_20171121_v0                    READY      ---
# BMA45DZ72HRGYW2KY72K7GPH  Export.image  VIIRS_reNDVI_20171201_v0                    READY      ---
# A4AL4JC5B7VESU2VFJIGEIHL  Export.image  VIIRS_reNDVI_20171211_v0                    READY      ---
# LKBEDZHN5JSCVNTL6SG44Y3F  Export.image  VIIRS_reNDVI_20171221_v0                    READY      ---
# NTWEHKNJE6SIP3GZ44RJLL3K  Export.image  VIIRS_reNDVI_20180101_v0                    READY      ---
# TKLADUH7HSCLNU7FRMW6UOQR  Export.image  VIIRS_reNDVI_20180111_v0                    READY      ---
# 2OHKMWE3EZW7TF5SPKFDFKX7  Export.image  VIIRS_reNDVI_20180121_v0                    READY      ---
# N6FMF54ZUB6BZINUY6MIJ2ES  Export.image  VIIRS_reNDVI_20180201_v0                    READY      ---
# ZENFHFKK2WGUDQT2T2FT36NL  Export.image  VIIRS_reNDVI_20180211_v0                    READY      ---
# 5UV3UFS2BG7XKLQYJE235FZX  Export.image  VIIRS_reNDVI_20180221_v0                    READY      ---
# YRE6MFRKGSQIUH7Q6YCV32PR  Export.image  VIIRS_reNDVI_20180301_v0                    READY      ---
# KGALFH2XWBB57FZCX4HRCBQ7  Export.image  VIIRS_reNDVI_20180311_v0                    READY      ---
# ADPTHLKVL3OU3LEZJK6ZTTVI  Export.image  VIIRS_reNDVI_20180321_v0                    READY      ---
# REXWQWUUYB23KIK4EZSDKVIL  Export.image  VIIRS_reNDVI_20180401_v0                    READY      ---
# QALQCFIZ56YAPNEMMIQH5GDA  Export.image  VIIRS_reNDVI_20180411_v0                    READY      ---
# A4XQWKG4Q3SQGBTXMVHLZ7XZ  Export.image  VIIRS_reNDVI_20180421_v0                    READY      ---
# 7SJZ4A5PUCDJIJHHH5Q6FI7K  Export.image  VIIRS_reNDVI_20180501_v0                    READY      ---
# 67GPITERXH2VWUIWC77RUS7Z  Export.image  VIIRS_reNDVI_20180511_v0                    READY      ---
# JL2N4YRSIYS67DLGAEIXO3IO  Export.image  VIIRS_reNDVI_20180521_v0                    RUNNING    ---
# ZTQ2OIFZ7IFCINRPO4YWN45W  Export.image  VIIRS_reNDVI_20180601_v0                    COMPLETED  ---
# CUCAC2X2ITO3CG5ALIBRWVN2  Export.image  VIIRS_reNDVI_20180611_v0                    RUNNING    ---
# OZINF2KNGZAA5E2IGTPLQ75K  Export.image  VIIRS_reNDVI_20180621_v0                    COMPLETED  ---
# ZNFGHTL77QDLMU5TGP7LKWX4  Export.image  VIIRS_reNDVI_20180701_v0                    COMPLETED  ---
# CFDFMKMB2BL4DPXMVVQPZODF  Export.image  VIIRS_reNDVI_20180711_v0                    COMPLETED  ---
# 42SGP5QQ6JLORPKN4WIF726V  Export.image  VIIRS_reNDVI_20180721_v0                    COMPLETED  ---
# 74NKOTXR24EQ4UM4ECQOHWX4  Export.image  VIIRS_reNDVI_20180801_v0                    COMPLETED  ---
# TICGQ4NPYBTHCPNQGWV7QXYB  Export.image  VIIRS_reNDVI_20180811_v0                    COMPLETED  ---
# QUPTERWJN2GPWMU7H4NOX7OH  Export.image  VIIRS_reNDVI_20180821_v0                    COMPLETED  ---
# GJOYHPU4EK3SZPVV5BCPW2OM  Export.image  VIIRS_reNDVI_20180901_v0                    COMPLETED  ---
# OGU563QQTIHTBGXSQNENGWSW  Export.image  VIIRS_reNDVI_20180911_v0                    COMPLETED  ---
# L4PBZ5NMXANIR3TDKMN33BSB  Export.image  VIIRS_reNDVI_20180921_v0                    COMPLETED  ---
# GPQ2YLDTOMXJCLEES2PEOW32  Export.image  VIIRS_reNDVI_20181001_v0                    COMPLETED  ---
# 7ESZJOJB2PTSPGOHYN2QDWOL  Export.image  VIIRS_reNDVI_20141001_v0                    FAILED     Cannot overwrite asset 'projects/earthengine-legacy/assets/projects/servir-e-sa/rangelands/reNDVI_viirs/VIIRS_reNDVI_20141001_v0'.
# YY7IU6SH4HJU5QGZAKFZED3W  Export.image  VIIRS_reNDVI_20141011_v0                    COMPLETED  ---
# BKHWKZRANYKWGKPWPMTRNDFH  Export.image  VIIRS_reNDVI_20141021_v0                    COMPLETED  ---
# 3T5MZXNSOUF2KNU64BTIK7YT  Export.image  VIIRS_reNDVI_20141101_v0                    COMPLETED  ---
# N32NOELN662ZSDN34XHS4LJ5  Export.image  VIIRS_reNDVI_20141111_v0                    COMPLETED  ---
# 2DJQOYS7KW6GG34FYY437FFL  Export.image  VIIRS_reNDVI_20141121_v0                    COMPLETED  ---
# 6M5OL3BBYE7IU7VGHSQGXRCP  Export.image  VIIRS_reNDVI_20141201_v0                    COMPLETED  ---
# 7X5XNCS2QKSK6GYQK4RH7WGI  Export.image  VIIRS_reNDVI_20141211_v0                    COMPLETED  ---
# KWELS7FNNSX25WRA3X6ZRTL2  Export.image  VIIRS_reNDVI_20141221_v0                    COMPLETED  ---
# KMIUKWUEDMEB3SDOOY7VK3GP  Export.image  VIIRS_reNDVI_20150101_v0                    COMPLETED  ---
# 453ZRARWCGQXAXPN37U7E5QE  Export.image  VIIRS_reNDVI_20150111_v0                    COMPLETED  ---
# VLI2LWA6CYTRM53G5DAJTKWQ  Export.image  VIIRS_reNDVI_20150121_v0                    COMPLETED  ---
# WKP5K7UBNGB3H7TLZO2ILBEK  Export.image  VIIRS_reNDVI_20150201_v0                    COMPLETED  ---
# ISVAEX5WZ63RW4SM6T2CH33J  Export.image  VIIRS_reNDVI_20150211_v0                    COMPLETED  ---
# 4LX7LXT4LYOQ4MRLTEP25OFI  Export.image  VIIRS_reNDVI_20150221_v0                    COMPLETED  ---
# YW5YLIPMWXWXIM62GRXHOSYO  Export.image  VIIRS_reNDVI_20150301_v0                    COMPLETED  ---
# X4NG3ZGWU2FAAWEBACP4WDIW  Export.image  VIIRS_reNDVI_20150311_v0                    COMPLETED  ---
# S4K3S56BHPZR2B2MGYNR4MGY  Export.image  VIIRS_reNDVI_20150321_v0                    COMPLETED  ---
# TJH7CSR23BXVFNYPUA3JESEE  Export.image  VIIRS_reNDVI_20150401_v0                    COMPLETED  ---
# YFM6OHCSW47D5ASDEYZVFRVQ  Export.image  VIIRS_reNDVI_20150411_v0                    COMPLETED  ---
# JAGR6EUMPL4QLRZNDTGIVA4U  Export.image  VIIRS_reNDVI_20150421_v0                    COMPLETED  ---
# KUYMB6576BIVPUVV5DS7J3OP  Export.image  VIIRS_reNDVI_20150501_v0                    COMPLETED  ---
# VJDBXTDVIZY3O6ZNBTAYBOAH  Export.image  VIIRS_reNDVI_20150511_v0                    COMPLETED  ---
# A7ZNOUXW5RAYF6EASCQA5IJE  Export.image  VIIRS_reNDVI_20150521_v0                    COMPLETED  ---
# R5YE2MECCELXW2VJQ6H2FQDA  Export.image  VIIRS_reNDVI_20150601_v0                    COMPLETED  ---
# 37QT6D6TAB2YCIKEKKGTRPUP  Export.image  VIIRS_reNDVI_20150611_v0                    COMPLETED  ---
# XRYCB5TK2YBNO5TX5RLRGY7I  Export.image  VIIRS_reNDVI_20150621_v0                    COMPLETED  ---
# ZWSMPFZADRJ5BMOQQFUJ7MLC  Export.image  VIIRS_reNDVI_20150701_v0                    COMPLETED  ---
# MDT7JLUCYUHIPRBYF6YGHWGP  Export.image  VIIRS_reNDVI_20150711_v0                    COMPLETED  ---
# L5TLKOXQLKR4Z2QM6LUYC3G2  Export.image  VIIRS_reNDVI_20150721_v0                    COMPLETED  ---
# XUNY4UPOSDRZYKCOBJOITRG7  Export.image  VIIRS_reNDVI_20150801_v0                    COMPLETED  ---
# FLDRIBTEY4GVSMQJ3DDH2WF5  Export.image  VIIRS_reNDVI_20150811_v0                    COMPLETED  ---
# KOVZA3G76BZ3QBQZM2QRXA4Y  Export.image  VIIRS_reNDVI_20150821_v0                    COMPLETED  ---
# 3BKBPE7GLHUMALNRUGAHOR4H  Export.image  VIIRS_reNDVI_20150901_v0                    COMPLETED  ---
# ZGSMQTECEREVJH2NCGBW5TKZ  Export.image  VIIRS_reNDVI_20150911_v0                    COMPLETED  ---
# CRMVXFFTF7Z2TZJDJJTCUS3G  Export.image  VIIRS_reNDVI_20150921_v0                    COMPLETED  ---
# 3U7JYXQRS2Q2RNOXZE7BTXQF  Export.image  VIIRS_reNDVI_20151001_v0                    COMPLETED  ---
# C3NE5ZYP7DB725VYH2S5XE2W  Export.image  VIIRS_reNDVI_20151011_v0                    COMPLETED  ---
# WSB2FT4N5RFH4O73KKB4W6WP  Export.image  VIIRS_reNDVI_20151021_v0                    COMPLETED  ---
# IPHSSI7YZM7CFBUKNCXFUELZ  Export.image  VIIRS_reNDVI_20151101_v0                    COMPLETED  ---
# MXP5FN4VZ6U4JBTNKIA4ZXLF  Export.image  VIIRS_reNDVI_20151111_v0                    COMPLETED  ---
# VDHFWQI6KSW4KPRXOJCLUQKA  Export.image  VIIRS_reNDVI_20151121_v0                    COMPLETED  ---
# VDSEDRYQEHIEIZ4DIEFSBR6H  Export.image  VIIRS_reNDVI_20151201_v0                    COMPLETED  ---
# XZYHVAS3JZHGTKBX7KND4T23  Export.image  VIIRS_reNDVI_20151211_v0                    COMPLETED  ---
# ZPQHMAACUUPISRFKIYUCUFPW  Export.image  VIIRS_reNDVI_20151221_v0                    COMPLETED  ---
# VEUJVB27TMRNWYAF5RC6WH7T  Export.image  VIIRS_reNDVI_20160101_v0                    COMPLETED  ---
# RUQQRADAGJXDQVGLR6PDN33S  Export.image  VIIRS_reNDVI_20160111_v0                    COMPLETED  ---
# Q6YRHPLRFVZYHU5ZY6D33M2H  Export.image  VIIRS_reNDVI_20160121_v0                    COMPLETED  ---
# PRQYFHP6A7XVBLYXV4SE7SDB  Export.image  VIIRS_reNDVI_20160201_v0                    COMPLETED  ---
# FN63EAW2JYGUWC34KSCGYMRC  Export.image  VIIRS_reNDVI_20160211_v0                    COMPLETED  ---
# UVW4JMWUQMX4DGRSI3VZVXZ2  Export.image  VIIRS_reNDVI_20160221_v0                    COMPLETED  ---
# UCEC7UDKU5VGPU3QB7QS3LLQ  Export.image  VIIRS_reNDVI_20160301_v0                    COMPLETED  ---
# KWKPZ2F6C4TOXDTNTDU2JK25  Export.image  VIIRS_reNDVI_20160311_v0                    COMPLETED  ---
# WUERKO5UZQ4PJCKCYH2EVELS  Export.image  VIIRS_reNDVI_20160321_v0                    COMPLETED  ---
# VTCMWNGCN27MXL4DCUXHI7QD  Export.image  VIIRS_reNDVI_20160401_v0                    COMPLETED  ---
# UTFM2M7252PRUQWVIF26IS2C  Export.image  VIIRS_reNDVI_20160411_v0                    COMPLETED  ---
# CXCTA7XRSLYBKGVAQJMYHTZY  Export.image  VIIRS_reNDVI_20160421_v0                    COMPLETED  ---
# XYP6RIV5LHAI3K4ZLG43IIKL  Export.image  VIIRS_reNDVI_20160501_v0                    COMPLETED  ---
# UUOFYTLMWZXLWTUAY52GIGHB  Export.image  VIIRS_reNDVI_20160511_v0                    COMPLETED  ---
# GDTFYADX4WAPD76WHU5QJRUO  Export.image  VIIRS_reNDVI_20160521_v0                    COMPLETED  ---
# 3BUX3BYDWHL3RVC6ROKOY3NH  Export.image  VIIRS_reNDVI_20160601_v0                    COMPLETED  ---
# QAKKNSCAZ5IIFGEC6YA6YHWB  Export.image  VIIRS_reNDVI_20160611_v0                    COMPLETED  ---
# V53MEXR5TAG2ATC6CUJPZDOW  Export.image  VIIRS_reNDVI_20160621_v0                    COMPLETED  ---
# KZPZQM4VBDU6BJTY4GIHETWK  Export.image  VIIRS_reNDVI_20160701_v0                    COMPLETED  ---
# IBKDMLWVVTYVV2AGYIXN7CM2  Export.image  VIIRS_reNDVI_20160711_v0                    COMPLETED  ---
# PQMM4YS3H3RFJ7A24GHKQM4G  Export.image  VIIRS_reNDVI_20160721_v0                    COMPLETED  ---
# JUGOP4J44IK3GFWQWJFHZOUX  Export.image  VIIRS_reNDVI_20160801_v0                    COMPLETED  ---
# ZECVQHBHSJF3ZEITLRESL3OR  Export.image  VIIRS_reNDVI_20160811_v0                    COMPLETED  ---
# PVYTCLVHPWQPYWAQY3AGWEOU  Export.image  VIIRS_reNDVI_20160821_v0                    COMPLETED  ---
# HGEUOBCPQTDNAQ272PRLGGKQ  Export.image  VIIRS_reNDVI_20160901_v0                    COMPLETED  ---
# 4AQIASUQBKHPI7JIYU2UTIN6  Export.image  VIIRS_reNDVI_20160911_v0                    COMPLETED  ---
# DAAGEWZJUZOK4YHEPS7BM5FY  Export.image  VIIRS_reNDVI_20160921_v0                    COMPLETED  ---
# MC5BGLCDCBVTUMTD5USCWKWB  Export.image  VIIRS_reNDVI_20161001_v0                    COMPLETED  ---
# HNUUNDRHIU776MQ2ATXUBNXH  Export.image  VIIRS_reNDVI_20120401_v0                    COMPLETED  ---
# GHIP7CJANAIALAIHXFDZJD4O  Export.image  VIIRS_reNDVI_20120411_v0                    COMPLETED  ---
# NNW4CP2RU3SDRX6OPWFLWXKW  Export.image  VIIRS_reNDVI_20120421_v0                    COMPLETED  ---
# RJJGEPWJW6FBISZY2THZGHAF  Export.image  VIIRS_reNDVI_20120501_v0                    COMPLETED  ---
# VBOJHJADP3RSYI3HEKGZK37G  Export.image  VIIRS_reNDVI_20120511_v0                    COMPLETED  ---
# WN3UZWU7CIEOKIMUBF7FJ2PO  Export.image  VIIRS_reNDVI_20120521_v0                    COMPLETED  ---
# VR2XJOAHDG7NZ5L5CZE3KZJY  Export.image  VIIRS_reNDVI_20120601_v0                    COMPLETED  ---
# RPQEO2R6RWVPGZR4WOXNWPMR  Export.image  VIIRS_reNDVI_20120611_v0                    COMPLETED  ---
# YKZNBRAM74FPC7TWPMLKNBRZ  Export.image  VIIRS_reNDVI_20120621_v0                    COMPLETED  ---
# VCRA545LILLI3ADYAYVTIU63  Export.image  VIIRS_reNDVI_20120701_v0                    COMPLETED  ---
# GT6DIUHK4KIIO5AZAETVE4JY  Export.image  VIIRS_reNDVI_20120711_v0                    COMPLETED  ---
# MHV44JBDUDYUSSPJ4BHGX2B3  Export.image  VIIRS_reNDVI_20120721_v0                    COMPLETED  ---
# JOABMCA6V7HAHIBISEWEAAMO  Export.image  VIIRS_reNDVI_20120801_v0                    COMPLETED  ---
# YXB5EFXP24RTGYN3D4SB2M4Q  Export.image  VIIRS_reNDVI_20120811_v0                    COMPLETED  ---
# SRLD5YDDIVTWLAGAJTUOU5PI  Export.image  VIIRS_reNDVI_20120821_v0                    COMPLETED  ---
# G4PBJHHKM3OU44J3ZYRNQGUE  Export.image  VIIRS_reNDVI_20120901_v0                    COMPLETED  ---
# F7REQD7RFAXD3UT537XCUTOX  Export.image  VIIRS_reNDVI_20120911_v0                    COMPLETED  ---
# AOQLP6KKMXRVIT7OJ2FF3QCG  Export.image  VIIRS_reNDVI_20120921_v0                    COMPLETED  ---
# OVZFKS6KC7G75FPTPRTYN7EC  Export.image  VIIRS_reNDVI_20121001_v0                    COMPLETED  ---
# P4IWCQ3JE3HFCCUYC6DH4NTE  Export.image  VIIRS_reNDVI_20121011_v0                    COMPLETED  ---
# GEQGEF5H3UUJRODJLJW6U435  Export.image  VIIRS_reNDVI_20121021_v0                    COMPLETED  ---
# KS4BPWPOEDDA2PSLT4KMUULR  Export.image  VIIRS_reNDVI_20121101_v0                    COMPLETED  ---
# LMBSYBB6XVPGP5NQ5E7SPPUD  Export.image  VIIRS_reNDVI_20121111_v0                    COMPLETED  ---
# 5JFP4ECNGYD2HJZG5QFORQK7  Export.image  VIIRS_reNDVI_20121121_v0                    COMPLETED  ---
# TFWHMORYSOISWFBYE5M42ALD  Export.image  VIIRS_reNDVI_20121201_v0                    COMPLETED  ---
# BXTBY6VFTFFLHEFSCQ5HSRVR  Export.image  VIIRS_reNDVI_20121211_v0                    COMPLETED  ---
# 5VSXTWZQGNLLFPVAHS2LH2B4  Export.image  VIIRS_reNDVI_20121221_v0                    COMPLETED  ---
# RFXZJ4KP45DH5DEBMTC63M52  Export.image  VIIRS_reNDVI_20130101_v0                    COMPLETED  ---
# LHS2CQRHRQDE2BQGU6BCBNHU  Export.image  VIIRS_reNDVI_20130111_v0                    COMPLETED  ---
# 4HXTTPXABIGITOQQ6MWKTVCC  Export.image  VIIRS_reNDVI_20130121_v0                    COMPLETED  ---
# VCR42NXQOOJ5M6AESVR5YBXT  Export.image  VIIRS_reNDVI_20130201_v0                    COMPLETED  ---
# MWYFP2G3YDNKV2XFBEWJSNQM  Export.image  VIIRS_reNDVI_20130211_v0                    COMPLETED  ---
# P7BCJL7UETJABAX7J7Y5A6U4  Export.image  VIIRS_reNDVI_20130221_v0                    COMPLETED  ---
# 3K7VTQPA2NWXEAPMW6KHKQLF  Export.image  VIIRS_reNDVI_20130301_v0                    COMPLETED  ---
# L2OGC4P3TXLAJ3M3RHMX6ZDS  Export.image  VIIRS_reNDVI_20130311_v0                    COMPLETED  ---
# DWVPLTMJU3YMPPUUSSXS2AG2  Export.image  VIIRS_reNDVI_20130321_v0                    COMPLETED  ---
# HF5EQDOPWTTYFA4RBLWHAFTE  Export.image  VIIRS_reNDVI_20130401_v0                    COMPLETED  ---
# MKVCOHOCPAG37PMJWV6ZNNQZ  Export.image  VIIRS_reNDVI_20130411_v0                    COMPLETED  ---
# A5W6GUAG3LYQZBBVNTRDY5XG  Export.image  VIIRS_reNDVI_20130421_v0                    COMPLETED  ---
# 5ZIX5GSMDTKOIDZJ2TEN4MFG  Export.image  VIIRS_reNDVI_20130501_v0                    COMPLETED  ---
# PRQIAGTTR5OCAV2N6S77DIS6  Export.image  VIIRS_reNDVI_20130511_v0                    COMPLETED  ---
# HZIW2QJNGFAJ54HEZUEZMEN3  Export.image  VIIRS_reNDVI_20130521_v0                    COMPLETED  ---
# TZDRGKBUYZEDG25QR6XXJDYB  Export.image  VIIRS_reNDVI_20130601_v0                    COMPLETED  ---
# J6OF6LM4Q2ERAP7JCZYQQYU4  Export.image  VIIRS_reNDVI_20130611_v0                    COMPLETED  ---
# D5BC2FQWJ447Y3P76IZPKCBZ  Export.image  VIIRS_reNDVI_20130621_v0                    COMPLETED  ---
# 5D76P43VTHRGT4IUA5QWOH2B  Export.image  VIIRS_reNDVI_20130701_v0                    COMPLETED  ---
# F7FLZAM7LOCDUD7NON4AUHLU  Export.image  VIIRS_reNDVI_20130711_v0                    COMPLETED  ---
# VH6G5CIM2CTZY75GQGHB5HUR  Export.image  VIIRS_reNDVI_20130721_v0                    COMPLETED  ---
# NLNSICNIVSXWGLO6CV2QPRHJ  Export.image  VIIRS_reNDVI_20130801_v0                    COMPLETED  ---
# 4VBQRWTK6N43UPPP4KNDPUHO  Export.image  VIIRS_reNDVI_20130811_v0                    COMPLETED  ---
# NYXS4TBPOQFFYZ7R3ALPWE7D  Export.image  VIIRS_reNDVI_20130821_v0                    COMPLETED  ---
# JIHV3LJBFB6CHQ5FJQDHHFKG  Export.image  VIIRS_reNDVI_20130901_v0                    COMPLETED  ---
# CUHHAP3K3TXLBZZHYINNYW7L  Export.image  VIIRS_reNDVI_20130911_v0                    COMPLETED  ---
# UEEG26HKVJYPDE7RAPMF5VCX  Export.image  VIIRS_reNDVI_20130921_v0                    COMPLETED  ---
# 2FJY5EVLDNUXEGMXDAFAIL2G  Export.image  VIIRS_reNDVI_20131001_v0                    COMPLETED  ---
# UGGFTZ6YJI3HO7VPSQGNW7XW  Export.image  VIIRS_reNDVI_20131011_v0                    COMPLETED  ---
# XJ2S7XCD5R67ARNQBKURVRJI  Export.image  VIIRS_reNDVI_20131021_v0                    COMPLETED  ---
# H4BZBHLHZOF4IIMBXEKYWK5C  Export.image  VIIRS_reNDVI_20131101_v0                    COMPLETED  ---
# 4PDETWDDODG7WZF6CFROJP7E  Export.image  VIIRS_reNDVI_20131111_v0                    COMPLETED  ---
# O7L3LXZUKBPJILUCXNJCIEBC  Export.image  VIIRS_reNDVI_20131121_v0                    COMPLETED  ---
# WOXR2FYGITJQQUHOHZZMVXWF  Export.image  VIIRS_reNDVI_20131201_v0                    COMPLETED  ---
# U32O45RHOTKUAAB3O4YMHRBJ  Export.image  VIIRS_reNDVI_20131211_v0                    COMPLETED  ---
# YLZJGZKQZVKV345P7HPGEUYK  Export.image  VIIRS_reNDVI_20131221_v0                    COMPLETED  ---
# 3ELT7OZ57KYZYHDU3WAAQ3GR  Export.image  VIIRS_reNDVI_20140101_v0                    COMPLETED  ---
# WMZUBEBVQ5RMFSTN4MCF3MGQ  Export.image  VIIRS_reNDVI_20140111_v0                    COMPLETED  ---
# D66WC54433YKO3N3GVSXWI6H  Export.image  VIIRS_reNDVI_20140121_v0                    COMPLETED  ---
# SVI5SNH3PJAZAVRG43UWXNZA  Export.image  VIIRS_reNDVI_20140201_v0                    COMPLETED  ---
# 4Y2I3TGKW6KNYJY2RBSUQSBD  Export.image  VIIRS_reNDVI_20140211_v0                    COMPLETED  ---
# QW5T5FA3M6MVNN6MI7SW2WIM  Export.image  VIIRS_reNDVI_20140221_v0                    COMPLETED  ---
# M45FQFXR47547G2HFD6KMZIH  Export.image  VIIRS_reNDVI_20140301_v0                    COMPLETED  ---
# ZKO7QCTDXVTB7KO35GJPCJT2  Export.image  VIIRS_reNDVI_20140311_v0                    COMPLETED  ---
# DUIJW4INTLQ4KKMGDUIB3S7G  Export.image  VIIRS_reNDVI_20140321_v0                    COMPLETED  ---
# N2VPW6WNV23CRNGHWQX7XNOV  Export.image  VIIRS_reNDVI_20140401_v0                    COMPLETED  ---
# IZM3Q6WC4SLHC6BKU4Q2JAXR  Export.image  VIIRS_reNDVI_20140411_v0                    COMPLETED  ---
# SUBLPIEDHLSGYLIMGCOZNN4R  Export.image  VIIRS_reNDVI_20140421_v0                    COMPLETED  ---
# 5Z5QOAXS3ER542M6WPU42CBV  Export.image  VIIRS_reNDVI_20140501_v0                    COMPLETED  ---
# YQ3ZBOLGFPZQXNDJHM7OETLR  Export.image  VIIRS_reNDVI_20140511_v0                    COMPLETED  ---
# F45WGA54O5SBJ5ADLGGN47A2  Export.image  VIIRS_reNDVI_20140521_v0                    COMPLETED  ---
# S6QP4HK3Q6UEW4R2LJP7QTHH  Export.image  VIIRS_reNDVI_20140601_v0                    COMPLETED  ---
# UV7FJUK7MEZUVYHU6DH6BWHE  Export.image  VIIRS_reNDVI_20140611_v0                    COMPLETED  ---
# 55SCYM2UWFH4VWCHDDUCIZUA  Export.image  VIIRS_reNDVI_20140621_v0                    COMPLETED  ---
# AGYYSSW4XZ2YIAGFUD6YOQTY  Export.image  VIIRS_reNDVI_20140701_v0                    COMPLETED  ---
# XWDZTOPFU3JMF2VBYGDX6GTR  Export.image  VIIRS_reNDVI_20140711_v0                    COMPLETED  ---
# 656URYXE7BY6YDUFHSUMJ5EA  Export.image  VIIRS_reNDVI_20140721_v0                    COMPLETED  ---
# F5TIFTX4FMVDNGJQXGBAMGSD  Export.image  VIIRS_reNDVI_20140801_v0                    COMPLETED  ---
# GZ6OYR4Y3S4OZRUQTCF2ZZLE  Export.image  VIIRS_reNDVI_20140811_v0                    COMPLETED  ---
# 4UKCDE6TM5PIWGI5JWV3TG4H  Export.image  VIIRS_reNDVI_20140821_v0                    COMPLETED  ---
# KYJK6IVECGEI5KKSLMTKONYI  Export.image  VIIRS_reNDVI_20140901_v0                    COMPLETED  ---
# ZGZEEVXBN4H2UVKT6BGHN3YD  Export.image  VIIRS_reNDVI_20140911_v0                    COMPLETED  ---
# U6NSZ7CPNRJTJRY5PAY3AJR3  Export.image  VIIRS_reNDVI_20140921_v0                    COMPLETED  ---
# EDL5IVRGMW2XZ2T3ZMHNH3LG  Export.image  VIIRS_reNDVI_20141001_v0                    COMPLETED  ---
# 4RCSUMVOJVJNPLPKPCO7HZOT  Export.table  hydrafloods_validation                      COMPLETED  ---
# KMFVFIHHVXPMONLEYVFISU46  Export.image  edge_mm2019_geeGrd_20190805                 COMPLETED  ---
# S6L726Z4OKYNKWPSU3MDVSZH  Export.image  edge_mm2019_geeGrd_20190802                 COMPLETED  ---
# YY6XWX32OJRSDLSAYBR7KA6B  Export.image  edge_mm2019_geeGrd_20190728                 COMPLETED  ---
# Q4P576JJ4QDNDGVSZDHZHRVC  Export.image  edge_mm2019_geeGrd_20190721                 COMPLETED  ---
# OV75EOTZ25J5VGL7SAOS4XKZ  Export.image  edge_mm2019_geeGrd_20190718                 COMPLETED  ---
# TD7R3M5BMWPOPP6A7OKFUT6Q  Export.image  edge_mm2019_geeGrd_20190716                 COMPLETED  ---
# TVT5NMUNRRWKVWDDS4NUCMGQ  Export.image  edge_mm2019_geeGrd_20190805                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# UWXJX2OQAP3HX6SP3M4ZJYJG  Export.image  bmax_mm2019_geeGrd_20190805                 COMPLETED  ---
# W3V5FUHYKCU3RJ7OLRXJVYZ7  Export.image  edge_mm2019_geeGrd_20190802                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# AQTOQQXVBMPZTSTXB7HXRCZP  Export.image  bmax_mm2019_geeGrd_20190802                 COMPLETED  ---
# KWX3VJIX6W2S7ZMZ3SXQYDUO  Export.image  edge_mm2019_geeGrd_20190728                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# Y6BWTJRZ4OJ3YOY425HK4OPR  Export.image  bmax_mm2019_geeGrd_20190728                 COMPLETED  ---
# PHPIUMMVKIDGPT7ZPAXGFSIG  Export.image  edge_mm2019_geeGrd_20190721                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# XLLJJVZMVDSGLYTDRFEJNYAY  Export.image  bmax_mm2019_geeGrd_20190721                 COMPLETED  ---
# ESR3K4G635FHPLBGAQYPRK5V  Export.image  edge_mm2019_geeGrd_20190718                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# CA5A3CVUEW4TRKTAXJAIEYG2  Export.image  bmax_mm2019_geeGrd_20190718                 COMPLETED  ---
# Z5SQJO3ODIYSMVKITXHF2HKL  Export.image  edge_mm2019_geeGrd_20190716                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# C5HVN5XEOT2XVFWTNTBAYI53  Export.image  bmax_mm2019_geeGrd_20190716                 COMPLETED  ---
# EPQGERCEALHTFAQBTQD2ZU5Y  Export.image  edge_mm2019_snapRtc_20190805                COMPLETED  ---
# 4QKCCJMSTVTANDUL3Q2XLZOH  Export.image  bmax_mm2019_snapRtc_20190805                COMPLETED  ---
# ZA2NJRHOLLT6E4K4NNHSXQM6  Export.image  edge_mm2019_snapRtc_20190802                COMPLETED  ---
# TJRTTMWESGATHIDVKPF6L6YM  Export.image  bmax_mm2019_snapRtc_20190802                COMPLETED  ---
# RCILVMI4FYT666WF3HCQZO5M  Export.image  edge_mm2019_snapRtc_20190728                COMPLETED  ---
# YQNRWUNFCKNO243V2IFEOMIR  Export.image  bmax_mm2019_snapRtc_20190728                COMPLETED  ---
# Y7BS4U7KSYZHRVUM3WQ3URC3  Export.image  bmax_mm2019_snapRtc_20190721                COMPLETED  ---
# 7SKH44B45FNGRCEFVKKCOY5V  Export.image  edge_mm2019_snapRtc_20190721                COMPLETED  ---
# AAQNNNQYDRTGSK6OHIEWMPX6  Export.image  edge_mm2019_snapRtc_20190718                COMPLETED  ---
# NVQ7DXILLMNCQJOM7NH6J7HK  Export.image  bmax_mm2019_snapRtc_20190718                COMPLETED  ---
# C23TY7QVZ2HKK3VNKWT6JM34  Export.image  edge_mm2019_snapRtc_20190716                COMPLETED  ---
# QJMYX7FLCEVEE6YDPSICZKO4  Export.image  bmax_mm2019_snapRtc_20190716                COMPLETED  ---
# WQVXVDRMJRTNICLIOV3AWLAW  Export.image  edge_kh2019_snapRtc_20191204                COMPLETED  ---
# UUDIUGMR6SEUESI6GGVFGEVB  Export.image  bmax_kh2019_snapRtc_20191204                COMPLETED  ---
# 72MZDQVXR447PMYDDVJZXT3X  Export.image  edge_kh2019_snapRtc_20191015                COMPLETED  ---
# AV367TC7UNILDAEGDJSX3V5M  Export.image  bmax_kh2019_snapRtc_20191015                COMPLETED  ---
# NRVFXJCEUF6KON74MOVZT6FY  Export.image  edge_kh2019_snapRtc_20191010                COMPLETED  ---
# O5TAWVEZVIPNBG5AAZNNAJER  Export.image  bmax_kh2019_snapRtc_20191010                COMPLETED  ---
# 77TE5YVWC7GFUBPCL22ORCPD  Export.image  edge_kh2019_snapRtc_20191005                COMPLETED  ---
# 5QXQJODREICOU3WTQEDWR733  Export.image  bmax_kh2019_snapRtc_20191005                COMPLETED  ---
# FTHBZWZV2TE5KLYGMH26Y7OP  Export.image  edge_kh2019_snapRtc_20191004                COMPLETED  ---
# TUZDBTAJK6T6VKV44KQYWPWA  Export.image  bmax_kh2019_snapRtc_20191004                COMPLETED  ---
# MWBD7SMIM4QTPTIJTT237YVJ  Export.image  edge_kh2019_snapRtc_20191003                COMPLETED  ---
# ZNIFXY6WT5UVQUIHSOCMXKVS  Export.image  bmax_kh2019_snapRtc_20191003                COMPLETED  ---
# PGN4S2YFTKOMFONK6UM5OMJC  Export.image  edge_kh2019_snapRtc_20190923                COMPLETED  ---
# C3LFEIUI6OKE2YWFY5OFV26K  Export.image  bmax_kh2019_snapRtc_20190923                COMPLETED  ---
# NYKQEKB2ZFVRM7THZSKR37DG  Export.image  edge_kh2019_snapRtc_20190921                COMPLETED  ---
# CWYKO3ZNEIFQZLG4KTMKSVHC  Export.image  bmax_kh2019_snapRtc_20190921                COMPLETED  ---
# LRJJFNRIXLLBQFSKR7V63SJL  Export.image  edge_kh2019_snapRtc_20190916                COMPLETED  ---
# W7D6RNBSBW2432LXK6IPZ6JB  Export.image  bmax_kh2019_snapRtc_20190916                COMPLETED  ---
# U3PJIBHMEX5UEH2CXW2SNE3L  Export.image  edge_kh2019_snapRtc_20190911                COMPLETED  ---
# ZH2RGMJ4HLWXMQDD6N35DY5P  Export.image  bmax_kh2019_snapRtc_20190911                COMPLETED  ---
# GQCJNSKMR3UY6X5LSGV2DBDU  Export.image  edge_kh2019_snapRtc_20190909                COMPLETED  ---
# OMHMNI4PQHLRJDMNHZZI3PEI  Export.image  bmax_kh2019_snapRtc_20190909                COMPLETED  ---
# 6JFS3DASZABA7WNBCPO5HKKE  Export.image  edge_kh2019_snapRtc_20190502                COMPLETED  ---
# 7NRZ6GR2S3LYKNCWFZEN3RUY  Export.image  bmax_kh2019_snapRtc_20190502                COMPLETED  ---
# NWXSIPQFI2HCIL7T4VJN4T3B  Export.image  edge_kh2019_snapRtc_20190501                COMPLETED  ---
# DD7WOKY7LSR6U5BEZIZ45M7V  Export.image  bmax_kh2019_snapRtc_20190501                COMPLETED  ---
# 5SGH66Y2CAXRHUKWRVR73EKN  Export.image  edge_kh2018_snapRtc_20180205                COMPLETED  ---
# DFI3Y4PLAFONRSLBWOFAGDDX  Export.image  bmax_kh2018_snapRtc_20180205                COMPLETED  ---
# VTIONYYNNVWZOPHBWRQKVLHW  Export.image  edge_kh2018_snapRtc_20180112                COMPLETED  ---
# SKJEFMC4BYCSJVOKUS45WOD7  Export.image  bmax_kh2018_snapRtc_20180112                COMPLETED  ---
# ENG4ZADFI2DJGJEK6VF2UWUQ  Export.image  edge_kh2018_snapRtc_20180111                COMPLETED  ---
# 44P4QG5FOODQF3TPFR6UBZIR  Export.image  bmax_kh2018_snapRtc_20180111                COMPLETED  ---
# OZ2FZQKMRY6K47UPVJLGA3LD  Export.image  edge_kh2018_snapRtc_20180104                COMPLETED  ---
# P22WBJAHDLC7N4ZU7BBVTL2I  Export.image  bmax_kh2018_snapRtc_20180104                COMPLETED  ---
# SURKSPXA6E27S34PUZ755WYG  Export.image  edge_kh2019_geeGrd_20191204                 COMPLETED  ---
# MVY5NTXF4XZJDO3YNGZTELGZ  Export.image  bmax_kh2019_geeGrd_20191204                 COMPLETED  ---
# RVBMR2J4TAS5OUFJWNNPXGYG  Export.image  edge_kh2019_geeGrd_20191015                 COMPLETED  ---
# XJBOSA23PRKMWK7QZHQY5Y2O  Export.image  bmax_kh2019_geeGrd_20191015                 COMPLETED  ---
# JJOCMTANDLRSQUJH7I6EAONF  Export.image  edge_kh2019_geeGrd_20191010                 COMPLETED  ---
# JDQLT7YUTHPRBR2MOBXKDIRI  Export.image  bmax_kh2019_geeGrd_20191010                 COMPLETED  ---
# 2SSDSA5HW3LOAGLHVGDOAXSN  Export.image  edge_kh2019_geeGrd_20191005                 COMPLETED  ---
# ZSZPHD7WGDK7X32ENLWPUNQC  Export.image  bmax_kh2019_geeGrd_20191005                 COMPLETED  ---
# TGMG5X753UJO5N5U2CMVM5P4  Export.image  edge_kh2019_geeGrd_20191004                 COMPLETED  ---
# WZ7HKZUOHIIWICMQ2DYAWECM  Export.image  bmax_kh2019_geeGrd_20191004                 COMPLETED  ---
# A7P7PGMA435DINM62LBYXUBU  Export.image  edge_kh2019_geeGrd_20191003                 COMPLETED  ---
# 6F7Z434BJNN6IGJYBEPCV6KJ  Export.image  bmax_kh2019_geeGrd_20191003                 COMPLETED  ---
# 3IEUSFVUNW7MAKWBX3KET24C  Export.image  edge_kh2019_geeGrd_20190923                 COMPLETED  ---
# 6YTSQ2SCTZSDYO625G5RSNK4  Export.image  bmax_kh2019_geeGrd_20190923                 COMPLETED  ---
# ZI76SOAZDYEWJW3WTFNVKLXC  Export.image  edge_kh2019_geeGrd_20190921                 COMPLETED  ---
# KF5UIZ4Q7ZMBGJTNGCTH7THA  Export.image  bmax_kh2019_geeGrd_20190921                 COMPLETED  ---
# DCFXG7QY53N7OIGAYV3HE23O  Export.image  edge_kh2019_geeGrd_20190916                 COMPLETED  ---
# GGMZTN6OWXAYUCE6CK5SDJK4  Export.image  bmax_kh2019_geeGrd_20190916                 COMPLETED  ---
# NKP3N73ULYWZAB42I7TCF7Q3  Export.image  edge_kh2019_geeGrd_20190911                 COMPLETED  ---
# 6MFZT4HWBA5EGZAB2LNQL2EL  Export.image  bmax_kh2019_geeGrd_20190911                 COMPLETED  ---
# ZN66AH65OZRG5ZLUFH7T6EZB  Export.image  edge_kh2019_geeGrd_20190909                 COMPLETED  ---
# PXGJCIEFYTLH4ENPP4RG2J7G  Export.image  bmax_kh2019_geeGrd_20190909                 COMPLETED  ---
# PWM7P5UALK5BF3RUMDITYF2R  Export.image  edge_kh2019_geeGrd_20190502                 COMPLETED  ---
# 3ACCVITK2SVJNHMGGHOFKMJC  Export.image  bmax_kh2019_geeGrd_20190502                 COMPLETED  ---
# CVQJN5TYJVCMMMSEDAYN56L5  Export.image  edge_kh2019_geeGrd_20190501                 COMPLETED  ---
# AGEOFXLZID22YI5SNEDQDN47  Export.image  bmax_kh2019_geeGrd_20190501                 COMPLETED  ---
# SHUZLCCFIGNTJ5OPQ3VOE5R3  Export.image  edge_kh2018_geeGrd_20180205                 COMPLETED  ---
# 47GVSGIMXVQ6ZOEJLSTCPLVM  Export.image  bmax_kh2018_geeGrd_20180205                 COMPLETED  ---
# NVYIOEI43NSXOVEV3FZHNIXN  Export.image  edge_kh2018_geeGrd_20180112                 COMPLETED  ---
# BABKBNGZVLYHFYHOTK74MMLD  Export.image  bmax_kh2018_geeGrd_20180112                 COMPLETED  ---
# Z53IGDYS37XUCZ2LAJHEZP4G  Export.image  edge_kh2018_geeGrd_20180111                 COMPLETED  ---
# 5IF6BUMBQF3TVN53W3IQZF25  Export.image  bmax_kh2018_geeGrd_20180111                 COMPLETED  ---
# CBUGS6DT7K5WMTYVA2LUAR4O  Export.image  edge_kh2018_geeGrd_20180104                 COMPLETED  ---
# BCJI75GYBCB7X2H6WEKXJGL7  Export.image  bmax_kh2018_geeGrd_20180104                 COMPLETED  ---
# F6DXN4XQYKWTZWEMSDCL6SHZ  Export.image  edge_kh2019_geeGrd_20180205                 CANCELLED  Cancelled.
# OPNSBIMX2Z6XURYOSXDMVDOW  Export.image  bmax_kh2019_geeGrd_20180205                 CANCELLED  Cancelled.
# NAZVCFAERZ463GPTEABYENF7  Export.image  edge_kh2019_geeGrd_20180112                 CANCELLED  Cancelled.
# BNKN2WZIIU7XG5VAQRRTRXI7  Export.image  bmax_kh2019_geeGrd_20180112                 CANCELLED  Cancelled.
# QLNCC5HS23OZY42AVT6TV46B  Export.image  edge_kh2019_geeGrd_20180111                 CANCELLED  Cancelled.
# REHDIFHCY7QOPW2R2TO3YOFD  Export.image  bmax_kh2019_geeGrd_20180111                 CANCELLED  Cancelled.
# CTV5KDNP4DAQP24JFLQWUUML  Export.image  edge_kh2019_geeGrd_20180104                 CANCELLED  Cancelled.
# EQVAEUBUSYCE35KFBEP4ZHGF  Export.image  bmax_kh2019_geeGrd_20180104                 CANCELLED  Cancelled.
# E5HJHHHG4BQY3YVJMEFWPA27  Export.image  edge_kh2019_geeGrd_20191204                 CANCELLED  Cancelled.
# FNHUM5EXKXY3OWG2N6TTDED5  Export.image  bmax_kh2019_geeGrd_20191204                 CANCELLED  Cancelled.
# PUCW2NXDRHX4IJIOTGNYZTEE  Export.image  edge_kh2019_geeGrd_20191015                 CANCELLED  Cancelled.
# QQWYAWKKLEAOECJFM43PW7PO  Export.image  bmax_kh2019_geeGrd_20191015                 CANCELLED  Cancelled.
# UPQTG332XBY2ZMRRUP2ZFZUG  Export.image  edge_kh2019_geeGrd_20191010                 CANCELLED  Cancelled.
# NLAIERNSNRFGVGD6NQWCLZHX  Export.image  bmax_kh2019_geeGrd_20191010                 CANCELLED  Cancelled.
# ZNUV7UZ4DKU3TLTPDMFUESQS  Export.image  edge_kh2019_geeGrd_20191005                 CANCELLED  Cancelled.
# EXBB3KJDBBSVC3MEX4XBDBRF  Export.image  bmax_kh2019_geeGrd_20191005                 CANCELLED  Cancelled.
# NTDGCQ2TMIHSCYUBGAZDLPNM  Export.image  edge_kh2019_geeGrd_20191004                 CANCELLED  Cancelled.
# GYSOWPGZBNNVN7XLCTGGTRB3  Export.image  bmax_kh2019_geeGrd_20191004                 CANCELLED  Cancelled.
# 2SN3M7B4G7NZMXWAERNZR4BI  Export.image  edge_kh2019_geeGrd_20191003                 CANCELLED  Cancelled.
# ARZ3UGXETACZDIOY54V642ZI  Export.image  bmax_kh2019_geeGrd_20191003                 CANCELLED  Cancelled.
# 3VVPOMCUSYNXBXQ4HFUQUGNF  Export.image  edge_kh2019_geeGrd_20190923                 CANCELLED  Cancelled.
# ROXAMENHMBMOX3WGNTQMTJGP  Export.image  bmax_kh2019_geeGrd_20190923                 CANCELLED  Cancelled.
# PZCOUJKBN6FVT7RAOGYMUSIH  Export.image  edge_kh2019_geeGrd_20190921                 CANCELLED  Cancelled.
# T7IFZGO3VIGK5N6OSHN5UM53  Export.image  bmax_kh2019_geeGrd_20190921                 CANCELLED  Cancelled.
# LTTC5BL7U3VCM6VKX6H27ZHP  Export.image  edge_kh2019_geeGrd_20190916                 CANCELLED  Cancelled.
# PGKUMHQGMPW2JS7TZFZAXUTJ  Export.image  bmax_kh2019_geeGrd_20190916                 CANCELLED  Cancelled.
# 53Y3WTTF44VUJE37ZMUTTLTY  Export.image  edge_kh2019_geeGrd_20190911                 CANCELLED  Cancelled.
# OLR6TBCUPZCH3YEUSNNUHAPO  Export.image  bmax_kh2019_geeGrd_20190911                 CANCELLED  Cancelled.
# DDTVNZJKX354XGULATBHQLS6  Export.image  edge_kh2019_geeGrd_20190909                 CANCELLED  Cancelled.
# 6IBUK3C6S4B3EBBNCWAOA3LS  Export.image  bmax_kh2019_geeGrd_20190909                 CANCELLED  Cancelled.
# 2UOVVZGWSUZBNZZHX6DIO3VA  Export.image  edge_kh2019_geeGrd_20190502                 CANCELLED  Cancelled.
# ZYLVE3L7F7IMYXHG3U37KA4J  Export.image  bmax_kh2019_geeGrd_20190502                 CANCELLED  Cancelled.
# BG3OOOTRGAQHFF3HXCMGQJ55  Export.image  edge_kh2019_geeGrd_20190501                 CANCELLED  Cancelled.
# IYT63KFGDKZMIGICJ35ENM3N  Export.image  bmax_kh2019_geeGrd_20190501                 CANCELLED  Cancelled.
# 7CCYHM3R5NOSV4VMPHPF6XMN  Export.image  bmax_kh2018_geeGrd_20180111                 CANCELLED  Cancelled.
# ROWOS4NNUV5EYC7F4TB62HXB  Export.image  edge_kh2018_geeGrd_20180205                 CANCELLED  Cancelled.
# URSYSBMJCUEYKBOYAXJJWZ6G  Export.image  bmax_kh2018_geeGrd_20180205                 CANCELLED  Cancelled.
# AVVVW7R2D26WRX2FC534ES6T  Export.image  edge_kh2018_geeGrd_20180112                 CANCELLED  Cancelled.
# YOZKYCMNH4IMKXHANGBFLQDL  Export.image  bmax_kh2018_geeGrd_20180112                 CANCELLED  Cancelled.
# 2PPG2YW3JETL7XRD4MIJOZTR  Export.image  edge_kh2018_geeGrd_20180111                 CANCELLED  Cancelled.
# 3CNY2VG2CQDYWBPTVT2OUZBO  Export.image  edge_kh2018_geeGrd_20180104                 CANCELLED  Cancelled.
# G7RAQRMYAC2UO42OIWRAY5II  Export.image  bmax_kh2018_geeGrd_20180104                 CANCELLED  Cancelled.
# 4L6KYNU2ISESRKWPQJ3CJTDL  Export.image  edge_kh2019_geeGrd_20180205                 CANCELLED  Cancelled.
# 7BXDB4JSDXRLBP5OYDRQ637F  Export.image  bmax_kh2019_geeGrd_20180205                 CANCELLED  Cancelled.
# 4KZBESLYPQ7NSTEGIT4EIAVQ  Export.image  edge_kh2019_geeGrd_20180112                 CANCELLED  Cancelled.
# ZHDJ57KQS3UEXUG7HKNYB5K3  Export.image  bmax_kh2019_geeGrd_20180112                 CANCELLED  Cancelled.
# EDGAZVUFLTHASFU7DM5Z7QVO  Export.image  edge_kh2019_geeGrd_20180111                 CANCELLED  Cancelled.
# GSPJRO3ZKSUECEYLRXSJUWQP  Export.image  bmax_kh2019_geeGrd_20180111                 CANCELLED  Cancelled.
# U63GAHCRBDLEXH3YKXXVCVZA  Export.image  edge_kh2019_geeGrd_20180104                 CANCELLED  Cancelled.
# VENJWSIVKMQXR4X72O5ZDXMD  Export.image  bmax_kh2019_geeGrd_20180104                 CANCELLED  Cancelled.
# R4AK6ZDYKMNW4VT4BV2QJRFG  Export.table  hydrafloods_validation                      COMPLETED  ---
# TZPKDRKFYPBOKNHI5EH7WV6M  Export.table  myExportTableTask                           FAILED     Image.select: Pattern 'bmax_*._geeGrd_*.' did not match any bands.
# XPTXK2TCYVVHLUCFB2YHUZCX  Export.table  hydrafloods_validation                      COMPLETED  ---
# JLFP47UV7HJLZJLKY3IMOYUG  Export.table  hydrafloods_validation                      COMPLETED  ---
# A7HI2RVXQEXZZX7RCMONVRPD  Export.table  hydrafloods_validation                      COMPLETED  ---
# JY6WQCMVHXLZXA4OPUTSXF7W  Upload        Ingest image: "projects/earthengine-lega..  COMPLETED  ---
# 4HTK3FCWXYRDCHWVOG2SVVPZ  Upload        Ingest image: "projects/earthengine-lega..  COMPLETED  ---
# TY6DYOP4ADOKND7ZEH62ENWU  Upload        Ingest image: "projects/earthengine-lega..  FAILED     Cannot overwrite asset 'projects/earthengine-legacy/assets/users/kelmarkert/icesat2_canopyh_dnn_prediction_california'.
# ABVSBCE77SSICNM4DKFNEE7J  Export.image  edge_kh2019_geeGrd_20191204                 COMPLETED  ---
# TRDHOBFLCSWIEIZLOBMG6D7Y  Export.image  edge_kh2019_geeGrd_20191015                 COMPLETED  ---
# SXLMVTXMGNHU2A5HVPTT5NMZ  Export.image  edge_kh2019_geeGrd_20191010                 COMPLETED  ---
# XD5VOZ7P3EJTHY4JTAIKDJ3V  Export.image  edge_kh2019_geeGrd_20191005                 COMPLETED  ---
# VCSOBIMZMKSYUROPI2F7EKXA  Export.image  edge_kh2019_geeGrd_20191004                 COMPLETED  ---
# MC2KTJV2PQJSZOIKT4MMWNB6  Export.image  edge_kh2019_geeGrd_20191003                 COMPLETED  ---
# 4KOFWCUVH365OKXVY5UWCIKS  Export.image  edge_kh2019_geeGrd_20190923                 COMPLETED  ---
# NGJKXJWALH66ZFBE343K6F4O  Export.image  edge_kh2019_geeGrd_20190921                 COMPLETED  ---
# HFIH3MFOG7Y3UU2MB2WGXT5Z  Export.image  edge_kh2019_geeGrd_20190916                 COMPLETED  ---
# LGGSVHR2JUZRWWWHELG5DAP3  Export.image  edge_kh2019_geeGrd_20190911                 COMPLETED  ---
# INCA5S3DFJTBUKJ6PRUOJ2AD  Export.image  edge_kh2019_geeGrd_20190909                 COMPLETED  ---
# 7UH5BXPK6I6H6QX2TPE63ITE  Export.image  edge_kh2019_geeGrd_20190502                 COMPLETED  ---
# XU6R66Y5JNXPK67GW2NRATZB  Export.image  edge_kh2019_geeGrd_20190501                 COMPLETED  ---
# BXFTX5HTOUMQNUQCQO5IN3FN  Export.image  edge_kh2018_geeGrd_20180205                 COMPLETED  ---
# Y7HFUBU7PY7W7SVKSAC3JWAB  Export.image  edge_kh2018_geeGrd_20180112                 COMPLETED  ---
# DS43MXDS2GE2ZVPHLCBICIDN  Export.image  edge_kh2018_geeGrd_20180111                 COMPLETED  ---
# NQPJ6CZ3QIQV2E6HC34F3KUD  Export.image  edge_kh2018_geeGrd_20180104                 COMPLETED  ---
# XRUGRJFVK23WQVFXWZ6JAPSD  Export.image  edge_mm2019_geeGrd_20190805                 COMPLETED  ---
# 6EUHTSYBIHJZJEM3CKY4WCN2  Export.image  edge_mm2019_geeGrd_20190802                 COMPLETED  ---
# EDL4SKA5QF7TSNXD5AGNW3O5  Export.image  edge_mm2019_geeGrd_20190728                 COMPLETED  ---
# VUSCJIGJA5XVWSGLSEJMXEPA  Export.image  edge_mm2019_geeGrd_20190721                 COMPLETED  ---
# CCVW4K6HTS4H7EOGN4X7AQUH  Export.image  edge_mm2019_geeGrd_20190716                 COMPLETED  ---
# PM4OJO6CPH5F6Q5IXW3UZDGG  Export.image  edge_mm2019_geeGrd_20190718                 COMPLETED  ---
# UOPDAAIFTU4ROYEIFTSHIXK2  Export.image  edge_kh2019_geeGrd_20191204                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# KRX7Q7AOK7E65OO7KZNQDELF  Export.image  edge_kh2019_geeGrd_20191015                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# TLZ757OIHWHNEEVCQMQXI3QY  Export.image  edge_kh2019_geeGrd_20191010                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# OFAWSUWR47YXIMXHUFPMFU4Y  Export.image  edge_kh2019_geeGrd_20191005                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# A3GPUA5ATIK7ELJBCKIGN3FY  Export.image  edge_kh2019_geeGrd_20191004                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# S3LTUXNGH4O7IGDYO43NBXZR  Export.image  edge_kh2019_geeGrd_20191003                 FAILED     Dictionary.get: Dictionary does not contain key: bucketMeans.
# ...
# K5UWDC3RJNSALMYBQ4AG3YWG  Export.image  edge_kh2018_snapRtc_20180104                CANCELLED  Cancelled.
# C2TY3EEX5UV5MUGXCZ74HYGA  Export.image  bmax_kh2018_snapRtc_20180104                COMPLETED  ---
# Z32NK6GULNNXNZV7K7TN2WLC  Export.image  edge_mm2019_snapRtc_20190805                CANCELLED  Cancelled.
# OLCA34KYG2JRVXJY4DZ5RUA6  Export.image  bmax_mm2019_snapRtc_20190805                COMPLETED  ---
# ITEWQ23OFHAJBVPH5R3RMKD6  Export.image  edge_mm2019_snapRtc_20190802                CANCELLED  Cancelled.
# YMK6D5C7KPQ4CYLPXLG6HOFM  Export.image  bmax_mm2019_snapRtc_20190802                COMPLETED  ---
# GKPDOT7AG24LZHG4QEETALMP  Export.image  bmax_mm2019_snapRtc_20190728                COMPLETED  ---
# 7SM4IGKID6T7NMAYAKA2IDC2  Export.image  edge_mm2019_snapRtc_20190728                COMPLETED  ---
# E4U3PGSN4XH3KD4GPUD2LXKS  Export.image  edge_mm2019_snapRtc_20190721                COMPLETED  ---
# MN5PSXJGG5CTWMTCGXF5V2ZQ  Export.image  bmax_mm2019_snapRtc_20190721                COMPLETED  ---
# AQOQAHK6BJVYWECF7IGVXSQH  Export.image  edge_mm2019_snapRtc_20190718                COMPLETED  ---
# A4VIQX2UNQ2DMDSVYL7NBQYB  Export.image  bmax_mm2019_snapRtc_20190718                COMPLETED  ---
# VNBL3MBYEJ6UEGSO44VSKTKN  Export.image  bmax_mm2019_snapRtc_20190716                COMPLETED  ---
# P6NEIOTDHTUMWLJFCLYP7DTC  Export.image  edge_mm2019_snapRtc_20190716                COMPLETED  ---
# C5Q7OD3QZVTONNWPHARMTXLE  Export.image  edge_kh2019_snapRtc_20191204                CANCELLED  Cancelled.
# FSCMOYAM27JQ6SUUDFLZ2X6P  Export.image  bmax_kh2019_snapRtc_20191204                CANCELLED  Cancelled.
# TYCNLTSGSL4P6IHQDQQ7VAYV  Export.image  edge_kh2019_snapRtc_20191015                CANCELLED  Cancelled.
# 55CMJE5TSMDSYUA2DKKDQYOU  Export.image  bmax_kh2019_snapRtc_20191015                CANCELLED  Cancelled.
# DYBOXEFBL4G6H56HTSGYHBJV  Export.image  edge_kh2019_snapRtc_20191010                CANCELLED  Cancelled.
# 5XV6ELGN4ER2NS66CEB7R6XV  Export.image  bmax_kh2019_snapRtc_20191010                CANCELLED  Cancelled.
# 5GUW2IV4JRRY5WBQITLFPK5Z  Export.image  edge_kh2019_snapRtc_20191005                CANCELLED  Cancelled.
# TYO6BCW6RZSDZCAPGAK6FOEB  Export.image  bmax_kh2019_snapRtc_20191005                CANCELLED  Cancelled.
# ORIAZJ4OH7SQVDPSG6WV54JA  Export.image  edge_kh2019_snapRtc_20191004                CANCELLED  Cancelled.
# GYZOQZCUWUJVBZNMRQLGDNYX  Export.image  bmax_kh2019_snapRtc_20191004                CANCELLED  Cancelled.
# XPPCWSHTDD2SKBSHLFUDIAHB  Export.image  edge_kh2019_snapRtc_20191003                CANCELLED  Cancelled.
# I3ULBGW7EWFH5KYTYK75V23C  Export.image  bmax_kh2019_snapRtc_20191003                CANCELLED  Cancelled.
# CINQF2AIOBYFTOX2HWEIDW2B  Export.image  edge_kh2019_snapRtc_20190923                CANCELLED  Cancelled.
# HNVMMWTWHSDGYH4T3BS4CF7K  Export.image  bmax_kh2019_snapRtc_20190923                CANCELLED  Cancelled.
# ZX56535HZQUZECOMN6JCJ2EW  Export.image  edge_kh2019_snapRtc_20190921                CANCELLED  Cancelled.
# HMLOWUR7H3HJ5CURZMWW4V3K  Export.image  bmax_kh2019_snapRtc_20190921                CANCELLED  Cancelled.
# OUL232AZBZGG7TNGGBB4MGZ6  Export.image  edge_kh2019_snapRtc_20190916                CANCELLED  Cancelled.
# 5XAL4CKNTSZY2U4LX7JFQFYU  Export.image  bmax_kh2019_snapRtc_20190916                CANCELLED  Cancelled.
# XV742CXUGVG7YTJUQQHGVJOZ  Export.image  edge_kh2019_snapRtc_20190911                CANCELLED  Cancelled.
# IIPYF7ZSHPVEDTEBE6ZNAFR6  Export.image  bmax_kh2019_snapRtc_20190911                CANCELLED  Cancelled.
# QEAD7GVJG27RRRUZ36SDJ4P3  Export.image  edge_kh2019_snapRtc_20190909                CANCELLED  Cancelled.
# CYWJYJC4O4EZW3IIDGWVIRZZ  Export.image  bmax_kh2019_snapRtc_20190909                CANCELLED  Cancelled.
# HTJ6C4BNMYE3XWA3KEZM5OZU  Export.image  edge_kh2019_snapRtc_20190502                CANCELLED  Cancelled.
# 3SIJSLZSOH2WSDDPJEJ2EOUG  Export.image  bmax_kh2019_snapRtc_20190502                CANCELLED  Cancelled.
# F2MIQTOX2JZBAGFZTUI7RCON  Export.image  edge_kh2019_snapRtc_20190501                CANCELLED  Cancelled.
# 6AHLDOR2ERL56D2TUHH2J7LT  Export.image  bmax_kh2019_snapRtc_20190501                CANCELLED  Cancelled.
# Y6D4U44WXRJWXVGI6JJQBEAI  Export.image  edge_kh2018_snapRtc_20180205                CANCELLED  Cancelled.
# GOUFED4PB5VWZTJJAXADKVHI  Export.image  bmax_kh2018_snapRtc_20180205                CANCELLED  Cancelled.
# ZIZFVUGYEU5JD4W3P5ACRE2M  Export.image  edge_kh2018_snapRtc_20180112                CANCELLED  Cancelled.
# AWY5BEURSMFJ3HIMHGSGZRU3  Export.image  bmax_kh2018_snapRtc_20180112                CANCELLED  Cancelled.
# MFU5SWMFWW3JOBA6QGJ44Z2F  Export.image  edge_kh2018_snapRtc_20180111                CANCELLED  Cancelled.
# ANKNNWMLJUPJVQPW4Z54GF5F  Export.image  bmax_kh2018_snapRtc_20180111                CANCELLED  Cancelled.
# KJSAVUTTRP7VFSFOXI3IC74M  Export.image  edge_kh2018_snapRtc_20180104                CANCELLED  Cancelled.
# HKGPSQAEDBPO5H3QCRDZELPL  Export.image  bmax_kh2018_snapRtc_20180104                CANCELLED  Cancelled.
# CFKOKOVYPEBFRMWLGOJKY22W  Export.image  edge_mm2019_snapRtc_20190805                CANCELLED  Cancelled.
# 26GRD74RSL3TNP5Y5QVTI6S4  Export.image  bmax_mm2019_snapRtc_20190805                CANCELLED  Cancelled.
# HGMWXHOSR5YT4B6CKMG2OCUN  Export.image  edge_mm2019_snapRtc_20190802                CANCELLED  Cancelled.
# JYEJ2FE3COIVK7Q5WFKSGULY  Export.image  bmax_mm2019_snapRtc_20190802                CANCELLED  Cancelled.
# P4LVOXVA5HD6VBYY5KE3VLJS  Export.image  edge_mm2019_snapRtc_20190728                CANCELLED  Cancelled.
# 2HNZIZFZWD26WJ6GPM5QK2DN  Export.image  bmax_mm2019_snapRtc_20190728                CANCELLED  Cancelled.
# G5SHBV74PP47GZRBFSDSPERI  Export.image  edge_mm2019_snapRtc_20190721                CANCELLED  Cancelled.
# 2CNLKWZWWAP6BLFNWSISLGYH  Export.image  bmax_mm2019_snapRtc_20190721                CANCELLED  Cancelled.
# YHINZNIW2FUWFM4KQPM732GY  Export.image  edge_mm2019_snapRtc_20190718                COMPLETED  ---
# 46ZT67LSBRAUGKZZQQ5B7PED  Export.image  bmax_mm2019_snapRtc_20190718                COMPLETED  ---
# TGHU3GCC3ZR7PIBCGQ7SCCUX  Export.image  edge_mm2019_snapRtc_20190716                COMPLETED  ---
# MXREOGODCJ6YHCKSDP2W6S34  Export.image  bmax_mm2019_snapRtc_20190716                COMPLETED  ---
# QA2PTEEARYSWKMED6NE3PJEU  Export.image  edge_kh2019_snapRtc_20191204                COMPLETED  ---
# 4QQPK4WMRYDGFMPLUILAXNYV  Export.image  bmax_kh2019_snapRtc_20191204                COMPLETED  ---
# HXITTOSXQ3522DWBT5S4HPBO  Export.image  edge_kh2019_snapRtc_20191010                COMPLETED  ---
# DHEQV6TEBGXEVGFIB7AS6ERY  Export.image  edge_kh2019_snapRtc_20191015                COMPLETED  ---
# 3VF36MDBWOAW67TJ6UUEYW7F  Export.image  bmax_kh2019_snapRtc_20191015                COMPLETED  ---
# SMFXVPI2BELAVNHMAC454BCJ  Export.image  bmax_kh2019_snapRtc_20191010                COMPLETED  ---
# EJ5KPJQO26GMTZUIROIZ5QXM  Export.image  edge_kh2019_snapRtc_20191005                COMPLETED  ---
# TLU6KBX53MCVYNIT72I3FGRR  Export.image  bmax_kh2019_snapRtc_20191005                COMPLETED  ---
# JXJZIKOFK7ZV46C52KMSKK3S  Export.image  edge_kh2019_snapRtc_20191004                COMPLETED  ---
# AECUDO4LTWNQR5MKXIOPKAWT  Export.image  bmax_kh2019_snapRtc_20191004                COMPLETED  ---
# HNEYSS6KNZYACDS7MYTRYR6I  Export.image  edge_kh2019_snapRtc_20191003                COMPLETED  ---
# 27ZCVVO4DGTAWTSRZ6XVEVQ3  Export.image  bmax_kh2019_snapRtc_20191003                COMPLETED  ---
# MH2K2E72SG6ELYOHRKVSBCNJ  Export.image  bmax_kh2019_snapRtc_20190923                COMPLETED  ---
# TUGKQIJZY6XNBWXWTLS5JE3J  Export.image  edge_kh2019_snapRtc_20190923                COMPLETED  ---
# 4GR2VOSM3Q7C2PIUUEIGVR54  Export.image  edge_kh2019_snapRtc_20190921                COMPLETED  ---
# Q7LAGIUCIH2PJPW7ARGJEF6Q  Export.image  bmax_kh2019_snapRtc_20190921                COMPLETED  ---
# V75GHRZDOFX5RJUBOEJO6HYI  Export.image  edge_kh2019_snapRtc_20190916                COMPLETED  ---
# J57DI4HTOC742AHPJIUR4VH3  Export.image  bmax_kh2019_snapRtc_20190916                COMPLETED  ---
# BVWLUW6EUAUFVYWXFKWDBTDK  Export.image  edge_kh2019_snapRtc_20190911                COMPLETED  ---
# 5U2WSFM7QQW5S7Y7RYCRDHLB  Export.image  bmax_kh2019_snapRtc_20190911                COMPLETED  ---
# 6LJ27TAEVMNVNJBAXWXVQMNB  Export.image  edge_kh2019_snapRtc_20190909                COMPLETED  ---
# VQOVPC3UX6CFGFSZ5WFUQCI4  Export.image  bmax_kh2019_snapRtc_20190909                COMPLETED  ---
# T72L3XMWEBZIEFUIKGDXDXAV  Export.image  edge_kh2019_snapRtc_20190502                COMPLETED  ---
# APRRR7MXRYMCAWWZV2ERBBVF  Export.image  bmax_kh2019_snapRtc_20190502                COMPLETED  ---
# QM63U5OITK4EOBEHZBRAOR7M  Export.image  edge_kh2019_snapRtc_20190501                COMPLETED  ---
# 7NZMJAUZMLWCN36TGABK437P  Export.image  bmax_kh2019_snapRtc_20190501                COMPLETED  ---
# ZNZNSLGZ3ADTXEICZDWBICL3  Export.image  edge_kh2018_snapRtc_20180205                COMPLETED  ---
# PCUVDQITYQ63CPTBLR4U5AMY  Export.image  bmax_kh2018_snapRtc_20180205                COMPLETED  ---
# SPBYCOGVGZJCTZYOQHG7JAGO  Export.image  edge_kh2018_snapRtc_20180112                COMPLETED  ---
# LG7TQXA2UBWJHBZEFGJ42LPR  Export.image  bmax_kh2018_snapRtc_20180112                COMPLETED  ---
# AY7I5EUKRHGZRTBT646UCWW3  Export.image  edge_kh2018_snapRtc_20180111                COMPLETED  ---
# HIFREEHTQWTSXZIFO4FSKYXZ  Export.image  bmax_kh2018_snapRtc_20180111                COMPLETED  ---
# A74TCEU72F6BQXLPH6SR4CNM  Export.image  edge_kh2018_snapRtc_20180104                COMPLETED  ---
# A67AVAW5AUAZDQ45BU4SQSMI  Export.image  bmax_kh2018_snapRtc_20180104                COMPLETED  ---
# AHEQBBNHWYITGHDVGIFXSYJA  Export.image  edge_mm2019_snapRtc_20190805                COMPLETED  ---
# HPLVWWUNF3OXIGAKY4KJKL32  Export.image  bmax_mm2019_snapRtc_20190805                COMPLETED  ---
# 3ZGCFXIL5YJR2JQGQ7F3VZWK  Export.image  edge_mm2019_snapRtc_20190802                COMPLETED  ---
# TFCDPFVIOXQTD472572OQ7YW  Export.image  bmax_mm2019_snapRtc_20190802                COMPLETED  ---
# PXE7GFLG5JTAQVL3T52CBB6G  Export.image  edge_mm2019_snapRtc_20190728                COMPLETED  ---
# HE4WGV5CBTE5YW2UWUHRQFPP  Export.image  bmax_mm2019_snapRtc_20190728                COMPLETED  ---
# RB5HOZNO57KPSPXFROCTMG4I  Export.image  edge_mm2019_snapRtc_20190721                COMPLETED  ---
# PQO6LCMEPYNPOC3J4KXNTXU2  Export.image  bmax_mm2019_snapRtc_20190721                COMPLETED  ---
# KSKQPCDUX2MUM6ZWDGHUHNKB  Export.image  edge_mm2019_snapRtc_20190718                COMPLETED  ---
# TSVCJZJLFVRYLFTKFJ7KGEQ7  Export.image  bmax_mm2019_snapRtc_20190718                COMPLETED  ---
# RE3NMRDEDDZXKVQLAT7OJSEA  Export.image  edge_mm2019_snapRtc_20190716                COMPLETED  ---
# NAN2CNPST6XZI5WQVYFDVR7Q  Export.image  bmax_mm2019_snapRtc_20190716                COMPLETED  ---
# RNQPPUA5EDH2AHATRSO5SKOY  Export.image  edge_kh2018_snapRtc_20180205                CANCELLED  Cancelled.
# 43ZL5CX474B6LGDAAUOMGXEI  Export.image  bmax_kh2018_snapRtc_20180205                CANCELLED  Cancelled.
# SA5SUARYJB7DIN3DMCMNFI6C  Export.image  edge_kh2018_snapRtc_20180112                CANCELLED  Cancelled.
# 3ASK3DAFK66OR74IP3I5LZS6  Export.image  bmax_kh2018_snapRtc_20180112                CANCELLED  Cancelled.
# M4NFO6E5LRFAUGPRP55II7FV  Export.image  edge_kh2018_snapRtc_20180111                CANCELLED  Cancelled.
# 4L5Q4KLCOSVGK274FQMKPHFR  Export.image  bmax_kh2018_snapRtc_20180111                CANCELLED  Cancelled.
# 33RTZUUNGMHQK6IDHOSGL4LD  Export.image  edge_kh2018_snapRtc_20180104                CANCELLED  Cancelled.
# VNPY6FMB77J3ZNE3HVG6HNWI  Export.image  bmax_kh2018_snapRtc_20180104                CANCELLED  Cancelled.
# HMHIVKZXPP2DOISHUWD3VH7Y  Export.image  edge_kh2019_snapRtc_20191204                CANCELLED  Cancelled.
# UB2AT6ESXYQNIWGFPUZVACBU  Export.image  bmax_kh2019_snapRtc_20191204                CANCELLED  Cancelled.
# 6REWBFR3ZDOHV5GK7E54ZVR6  Export.image  edge_kh2019_snapRtc_20191015                CANCELLED  Cancelled.
# VM3ZRAWOLC2RMBQSRQXFFRPI  Export.image  bmax_kh2019_snapRtc_20191015                CANCELLED  Cancelled.
# ZKTG4ILUGZNB3BHMWKQVJ2O4  Export.image  edge_kh2019_snapRtc_20191010                CANCELLED  Cancelled.
# V6G2U7WVFMMLT32KUUVUEAU2  Export.image  bmax_kh2019_snapRtc_20191010                CANCELLED  Cancelled.
# OHKMBM7YYL4L5PQX5I43A4YP  Export.image  edge_kh2019_snapRtc_20191005                CANCELLED  Cancelled.
# YDTD756ZP2IMHEN7U3QD7UPQ  Export.image  bmax_kh2019_snapRtc_20191005                CANCELLED  Cancelled.
# BM6YZCBQPAJBXNSSI7MTUYZS  Export.image  edge_kh2019_snapRtc_20191004                CANCELLED  Cancelled.
# S5ONURQB2OVSLQWIH6C3XHTV  Export.image  bmax_kh2019_snapRtc_20191004                CANCELLED  Cancelled.
# NN4N7C6S7IIIZDTDTW7HHM2C  Export.image  edge_kh2019_snapRtc_20191003                CANCELLED  Cancelled.
# 4AB4NH7MFYMGC6SBBUPM5XSL  Export.image  bmax_kh2019_snapRtc_20191003                CANCELLED  Cancelled.
# YTEVGGVOKMQ6TY2A7I45JKJP  Export.image  edge_kh2019_snapRtc_20190923                CANCELLED  Cancelled.
# V27ZIF3XX37UKH2I5SBCU2FK  Export.image  bmax_kh2019_snapRtc_20190923                CANCELLED  Cancelled.
# W4GUG2SQHNL3OSS5QP2O6YS2  Export.image  edge_kh2019_snapRtc_20190921                CANCELLED  Cancelled.
# KY2WZDKFLGEEY7ZTCFLHRMQV  Export.image  bmax_kh2019_snapRtc_20190921                CANCELLED  Cancelled.
# ICOABHP2ZVFEAGR4ZJ4VQQ4I  Export.image  edge_kh2019_snapRtc_20190916                CANCELLED  Cancelled.
# L3RN4V3UEPV3ADEKBQC6J4JU  Export.image  bmax_kh2019_snapRtc_20190916                CANCELLED  Cancelled.
# H7HWEAFCPQBE64CUYVGDEYMA  Export.image  edge_kh2019_snapRtc_20190911                CANCELLED  Cancelled.
# UZZBXPOJAY6ONJRWGTHQM35J  Export.image  bmax_kh2019_snapRtc_20190911                CANCELLED  Cancelled.
# SIGUWGD7AZMTIOZTFNXVQBNL  Export.image  edge_kh2019_snapRtc_20190909                CANCELLED  Cancelled.
# YDIJUPZOXVIVY243S65BCCLA  Export.image  bmax_kh2019_snapRtc_20190909                CANCELLED  Cancelled.
# VEE3PX76JSKNHG44OBXNPV7N  Export.image  edge_kh2019_snapRtc_20190502                CANCELLED  Cancelled.
# 3AYMNSPBPD6UKZLXKDVEINWS  Export.image  bmax_kh2019_snapRtc_20190502                CANCELLED  Cancelled.
# XYT6BNBEBORFJAT4BAPE6HLC  Export.image  edge_kh2019_snapRtc_20190501                CANCELLED  Cancelled.
# PSHCG3OQ2ILFPRQCMQ5QEJQW  Export.image  bmax_kh2019_snapRtc_20190501                CANCELLED  Cancelled.
# NDN6ZAR5CLZWVKUJIOAMLESM  Export.image  edge_mm2019_snapRtc_20190805                CANCELLED  Cancelled.
# RTL6SHCNUFA73WHGGXSQCBBA  Export.image  bmax_mm2019_snapRtc_20190805                CANCELLED  Cancelled.
# N6UJJM7DO2FCHPL42YOR4DFN  Export.image  edge_mm2019_snapRtc_20190802                CANCELLED  Cancelled.
# W4Q3DVKZDMEDLE4CZTV2UIL2  Export.image  bmax_mm2019_snapRtc_20190802                CANCELLED  Cancelled.
# KQX26LKYBG2YLML22SBDUCN3  Export.image  edge_mm2019_snapRtc_20190728                CANCELLED  Cancelled.
# ZNYWLVEMBNZN7IR4LL3YI7F4  Export.image  bmax_mm2019_snapRtc_20190728                CANCELLED  Cancelled.
# MXHR2QVL7LZB2DICOVRNUUK6  Export.image  edge_mm2019_snapRtc_20190721                CANCELLED  Cancelled.
# ICFBU3AIJSXEYX22NMC54HEO  Export.image  bmax_mm2019_snapRtc_20190721                CANCELLED  Cancelled.
# NDCHAWXB52MIK5LMZVJXX3K3  Export.image  edge_mm2019_snapRtc_20190718                COMPLETED  ---
# ZHDVJUB2HETCRKWKP72O4P4F  Export.image  bmax_mm2019_snapRtc_20190718                COMPLETED  ---
# IW44MIPYEBY2KIXQQ4KT2GKJ  Export.image  edge_mm2019_snapRtc_20190716                COMPLETED  ---
# C66GVGIYV7KNAXIEKZRHWIKY  Export.image  bmax_mm2019_snapRtc_20190716                COMPLETED  ---
# TMTFMPNT4WXXEC5CIHYUIBI7  Export.image  bmax_mm2019_geeGrd_20190721                 COMPLETED  ---
# GBII5Y7ZJ6YWWQWXSMYIGAO7  Export.image  edge_mm2019_geeGrd_20190728                 COMPLETED  ---
# FAEOH5LPPLLA6HGVYF3GG5FE  Export.image  edge_kh2018_geeGrd_20180205                 COMPLETED  ---
